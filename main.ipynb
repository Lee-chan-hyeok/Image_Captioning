# %%
import torch
import pickle
import osd
import sys
from argparse import ArgumentParser
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import pickle
#       3 import osd
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] 지정된 모듈을 찾을 수 없습니다. Error loading "C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
from ipynb.fs.full. config import Config
from ipynb.fs.full. train_edit import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ipynb.fs.full. config import Config
#       2 from ipynb.fs.full. train_edit import *
#
# ModuleNotFoundError: No module named 'ipynb'

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 device = torch.device('cuda:0') if torch.cuda.is_available() else 'cpu'
#       2 print(device)
#
# NameError: name 'torch' is not defined

# %%
config_path = 'config.json'
config = Config(config_path)

#trainer = Trainer(config, device, 'train', 0)

# %%
#with open('data/modeling/trainer.p', 'wb') as f:
#   pickle.dump(trainer, f)

with open('data/modeling/trainer.p', 'rb') as f:
    trainer = pickle.load(f)

# %%
model_train(trainer)
# Out:
# ********** epoch start **********
# 1 / 3
# ----------
# Phase: train
# -------------------- enumer start --------------------
# line 60, decoder all output torch.Size([32, 32, 162])
# line 63, loss is tensor(5.1348, grad_fn=<NllLossBackward0>)
# line 71, acc 2.849740932642487
# total_loss is 186.72117614746094, total_acc is 91.19170984455958
# Epoch 1: 0/2 step loss: 5.835036754608154, top-5 acc: 2.849740932642487
# line 60, decoder all output torch.Size([8, 32, 162])
# line 63, loss is tensor(4.9048, grad_fn=<NllLossBackward0>)
# line 71, acc 20.833333333333336
# total_loss is 231.59200286865234, total_acc is 257.85837651122625
# -------------------- enumer end --------------------
# train loss: 5.789800071716309, top-5 acc: 6.446459412780657
#
# Phase: test
# -------------------- enumer start --------------------
# line 60, decoder all output torch.Size([10, 32, 162])
# line 63, loss is tensor(4.8072)
# line 71, acc 16.101694915254235
# total_loss is 55.08268356323242, total_acc is 161.01694915254234
# Epoch 1: 0/1 step loss: 5.508268356323242, top-5 acc: 16.101694915254235
# -------------------- enumer end --------------------
# test loss: 5.508268356323242, top-5 acc: 16.101694915254235
#
# --------------------------------------------------
# gt  : a girl going into a wooden [UNK]
# pred: a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
#
# gt  : a little girl climbing on red [UNK]
# pred: a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
#
# gt  : dog with orange ball at [UNK] [UNK] on shore [UNK] [UNK] water
# pred: a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
#
# --------------------------------------------------
#
# line 100, print sample done..
# tensor2list done
# <class 'list'>
# [[['a', 'girl', 'going', 'into', 'a', 'wooden', '[UNK]']], [['a', 'dog', 'shakes', '[UNK]', 'head', 'near', 'the', 'shore', 'a', 'red', 'ball', 'next', 'to', 'it']], [['dog', 'with', 'orange', 'ball', 'at', '[UNK]', '[UNK]', 'on', 'shore', '[UNK]', '[UNK]', 'water']], [['[UNK]', 'boy', 'in', 'white', '[UNK]', 'and', 'blue', '[UNK]', 'in', 'front', 'of', '[UNK]', 'wall', 'with', 'man', 'in', 'overalls', 'behind', 'him']], [['[UNK]', 'is', 'a', 'girl', 'with', 'pigtails', 'sitting', 'in', 'front', 'of', 'a', 'rainbow', 'painting']], [['a', 'man', 'lays', 'on', 'a', 'bench', 'while', 'his', 'dog', 'sits', 'by', 'him']], [['man', '[UNK]', 'on', 'bench', '[UNK]', '[UNK]', 'of', 'dog', 'sitting', 'on', '[UNK]']], [['the', 'man', 'with', '[UNK]', 'ears', 'is', 'wearing', 'glasses', 'and', 'an', 'orange', 'hat']], [['a', 'little', 'girl', 'climbing', 'on', 'red', '[UNK]']], [['the', 'small', 'child', 'climbs', 'on', 'a', 'red', 'ropes', 'on', 'a', 'playground']]]
# blew2 append done
# blew4 append done
# bbbbb
# nist2 append done
# bbbbb
# nist4 append done
# topk acc append done
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model_train(trainer)
#
# File c:\Users\USER\Desktop\DA\project\Img Captioning\train_edit.ipynb:239, in model_train(Trainer)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 5,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import torch\n",
#      10     "import torch.nn as nn\n",
#      11     "import torch.optim as optim\n",
#      12     "import torchvision.transforms as transforms\n",
#      13     "from torch.utils.data import DataLoader\n",
#      14     "\n",
#      15     "import copy\n",
#      16     "import pickle\n",
#      17     "import numpy as np\n",
#      18     "import time\n",
#      19     "import sys"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "code",
#      24    "execution_count": 6,
#      25    "metadata": {},
#      26    "outputs": [],
#      27    "source": [
#      28     "from ipynb.fs.full. my_tk import My_tokenizer\n",
#      29     "from ipynb.fs.full. config import Config\n",
#      30     "from ipynb.fs.full. utils_data import DLoader\n",
#      31     "from ipynb.fs.full. utils_func import *\n",
#      32     "from ipynb.fs.full. model_ino import *"
#      33    ]
#      34   },
#      35   {
#      36    "cell_type": "code",
#      37    "execution_count": 7,
#      38    "metadata": {},
#      39    "outputs": [],
#      40    "source": [
#      41     "class Trainer:\n",
#      42     "    def __init__(self, config:Config, device:torch.device, mode:str, continuous:int):\n",
#      43     "        self.config = config\n",
#      44     "        self.device = device\n",
#      45     "        self.mode = mode\n",
#      46     "        self.continuous = continuous\n",
#      47     "        self.dataloaders = {}\n",
#      48     "\n",
#      49     "        self.model = {}\n",
#      50     "        self.loss_data = {}\n",
#      51     "\n",
#      52     "        # if continuous, load previous training info\n",
#      53     "        if self.continuous:\n",
#      54     "            with open(self.config.loss_data_path, 'rb') as f:\n",
#      55     "                self.loss_data = pickle.load(f)\n",
#      56     "\n",
#      57     "        # path, data params\n",
#      58     "        self.base_path = self.config.base_path\n",
#      59     "        self.model_path = self.config.model_path\n",
#      60     "\n",
#      61     "        # train params\n",
#      62     "        self.batch_size = self.config.batch_size\n",
#      63     "        self.epochs = self.config.epochs\n",
#      64     "        self.enc_lr = self.config.enc_lr\n",
#      65     "        self.dec_lr = self.config.dec_lr\n",
#      66     "\n",
#      67     "        # model params\n",
#      68     "        self.img_size = self.config.img_size\n",
#      69     "        self.max_len = self.config.max_len\n",
#      70     "\n",
#      71     "        # for reproducibility\n",
#      72     "        torch.manual_seed(999)\n",
#      73     "\n",
#      74     "        # set transforms (ImageNet mean, std because pre-trained ResNet101 trained by ImageNet)\n",
#      75     "        mean = [0.485, 0.456, 0.406]\n",
#      76     "        std = [0.229, 0.224, 0.225]\n",
#      77     "        self.trans = transforms.Compose([\n",
#      78     "            transforms.Resize((self.img_size, self.img_size)), \n",
#      79     "            transforms.ToTensor(),\n",
#      80     "            transforms.Normalize(mean, std)])\n",
#      81     "\n",
#      82     "        # make dataset\n",
#      83     "        self.img_folder = self.base_path + 'data/Images/'\n",
#      84     "        self.caption_file = self.base_path + 'data/captions.txt'\n",
#      85     "        self.all_pairs = collect_all_pairs(self.caption_file)\n",
#      86     "        \n",
#      87     "        # 편의상 400개까지\n",
#      88     "        self.all_pairs = self.all_pairs[:74]\n",
#      89     "        self.trainset_id, self.valset_id = make_dataset_ids(len(self.all_pairs), 10)\n",
#      90     "        self.tokenizer = My_tokenizer(self.config, self.all_pairs, self.trainset_id)\n",
#      91     "\n",
#      92     "        # train set\n",
#      93     "        if self.mode == 'train':\n",
#      94     "            self.trainset = DLoader(self.img_folder, self.all_pairs, self.trans, self.trainset_id, self.tokenizer, self.max_len)\n",
#      95     "            self.dataloaders['train'] = DataLoader(self.trainset, batch_size=self.batch_size, shuffle=True, num_workers=4)\n",
#      96     "        \n",
#      97     "        # val set\n",
#      98     "        self.valset = DLoader(self.img_folder, self.all_pairs, self.trans, self.valset_id, self.tokenizer, self.max_len)\n",
#      99     "        self.dataloaders['test'] = DataLoader(self.valset, batch_size=self.batch_size, shuffle=False, num_workers=4)\n",
#     100     "\n",
#     101     "        # model, optimizer, loss\n",
#     102     "        self.encoder = Encoder(self.config).to(self.device)\n",
#     103     "        self.decoder = Decoder(self.config, self.tokenizer).to(self.device)\n",
#     104     "        self.criterion = nn.CrossEntropyLoss(ignore_index=self.tokenizer.pad_token_id)\n",
#     105     "\n",
#     106     "        # 훈련시킬 경우 -> 옵티마이저, 러닝레이트 필요\n",
#     107     "        if self.mode == 'train':\n",
#     108     "            # encoder, decoder optimizer 설정\n",
#     109     "            self.enc_optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, self.encoder.parameters()), lr=self.enc_lr)\n",
#     110     "            self.dec_optimizer = optim.Adam(self.decoder.parameters(), lr=self.dec_lr)\n",
#     111     "\n",
#     112     "            # 이어서 학습할 경우\n",
#     113     "            if self.continuous:\n",
#     114     "                self.check_point = torch.load(self.model_path, map_location=self.device)\n",
#     115     "                self.encoder.load_state_dict(self.check_point['model']['encoder'])\n",
#     116     "                self.decoder.load_state_dict(self.check_point['model']['decoder'])\n",
#     117     "                self.enc_optimizer.load_state_dict(self.check_point['optimizer']['encoder'])\n",
#     118     "                self.dec_optimizer.load_state_dict(self.check_point['optimizer']['decoder'])\n",
#     119     "                del self.check_point\n",
#     120     "                torch.cuda.empty_cache()\n",
#     121     "        \n",
#     122     "        # 테스트, 추론할 경우\n",
#     123     "        elif self.mode == 'test' or self.mode == 'inference':\n",
#     124     "            self.trans4attn = transforms.Compose([\n",
#     125     "                transforms.Resize((252, 252)),\n",
#     126     "                transforms.ToTensor()])\n",
#     127     "            self.check_point = torch.load(self.model_path, map_location=self.device)\n",
#     128     "            self.encoder.load_state_dict(self.check_point['model']['encoder'])\n",
#     129     "            self.decoder.load_state_dict(self.check_point['model']['decoder'])\n",
#     130     "            self.encoder.eval()\n",
#     131     "            self.decoder.eval()\n",
#     132     "            del self.check_point\n",
#     133     "            torch.cuda.empty_cache()"
#     134    ]
#     135   },
#     136   {
#     137    "cell_type": "code",
#     138    "execution_count": 8,
#     139    "metadata": {},
#     140    "outputs": [],
#     141    "source": [
#     142     "def model_train(Trainer):\n",
#     143     "    early_stop = 0\n",
#     144     "\n",
#     145     "    # 사전학습 유무\n",
#     146     "    best_val_bleu = 0 if not Trainer.continuous else Trainer.loss_data['best_val_bleu']\n",
#     147     "    train_loss_history = [] if not Trainer.continuous else Trainer.loss_data['train_loss_history']\n",
#     148     "    val_loss_history = [] if not Trainer.continuous else Trainer.loss_data['val_loss_history']\n",
#     149     "    val_score_history = {'bleu2': [], 'bleu4': [], 'nist2': [], 'nist4': [], 'topk_acc': []} if not Trainer.continuous else Trainer.loss_data['val_score_history']\n",
#     150     "    best_epoch_info = 0 if not Trainer.continuous else Trainer.loss_data['best_epoch']\n",
#     151     "\n",
#     152     "    for epoch in range(Trainer.epochs):\n",
#     153     "        print('*'*10, 'epoch start', '*'*10)\n",
#     154     "        start = time.time() # epoch 시작\n",
#     155     "        print(epoch + 1, '/', Trainer.epochs)\n",
#     156     "        print('-'*10)\n",
#     157     "\n",
#     158     "        for phase in ['train', 'test']:\n",
#     159     "            print('Phase: {}'.format(phase))\n",
#     160     "\n",
#     161     "            if phase == 'train':    # train인 경우\n",
#     162     "                Trainer.encoder.train()\n",
#     163     "                Trainer.decoder.train()\n",
#     164     "            else:                   # test인 경우\n",
#     165     "                Trainer.encoder.eval()\n",
#     166     "                Trainer.decoder.eval()\n",
#     167     "\n",
#     168     "            total_loss, total_acc = 0, 0\n",
#     169     "            all_val_trg, all_val_output = [], []\n",
#     170     "\n",
#     171     "            print('-'*20, 'enumer start', '-'*20)\n",
#     172     "            for i, (img, cap, _) in enumerate(Trainer.dataloaders[phase]):\n",
#     173     "\n",
#     174     "                batch_size = img.size(0)\n",
#     175     "                #print('in train_model, line 32')\n",
#     176     "                #print('shape = ', img.shape)\n",
#     177     "                \n",
#     178     "                img, cap = img.to(Trainer.device), cap.to(Trainer.device)\n",
#     179     "                Trainer.enc_optimizer.zero_grad()\n",
#     180     "                Trainer.dec_optimizer.zero_grad()\n",
#     181     "\n",
#     182     "                # train이면 grad 변화\n",
#     183     "                with torch.set_grad_enabled(phase=='train'):\n",
#     184     "                    enc_output, hidden = Trainer.encoder(img)\n",
#     185     "                    \n",
#     186     "                    decoder_all_output, decoder_all_score = [], []\n",
#     187     "\n",
#     188     "                    #print('line 45, max_len = ', Trainer.max_len)\n",
#     189     "                    \n",
#     190     "                    for j in range(Trainer.max_len):\n",
#     191     "                        trg_word = cap[:, j].unsqueeze(1)\n",
#     192     "                        dec_output, hidden, score = Trainer.decoder(trg_word, hidden, enc_output)\n",
#     193     "                        #print('decoding')\n",
#     194     "                        decoder_all_output.append(dec_output)\n",
#     195     "                        #print('append')\n",
#     196     "                        \n",
#     197     "                        # Attention layer면\n",
#     198     "                        if Trainer.config.is_attn:\n",
#     199     "                            #print('into append')\n",
#     200     "                            decoder_all_score.append(score)\n",
#     201     "                            #print('if append')\n",
#     202     "\n",
#     203     "                    decoder_all_output = torch.cat(decoder_all_output, dim= 1)\n",
#     204     "                    print('line 60, decoder all output', decoder_all_output.shape)\n",
#     205     "\n",
#     206     "                    loss = Trainer.criterion(decoder_all_output[:, :-1, :].reshape(-1, decoder_all_output.size(-1)), cap[:, 1:].reshape(-1))\n",
#     207     "                    print('line 63, loss is', loss)\n",
#     208     "\n",
#     209     "                    if Trainer.config.is_attn:\n",
#     210     "                        decoder_all_score = torch.cat(decoder_all_score, dim=2)\n",
#     211     "                        loss += Trainer.config.regularization_lambda * ((1. - torch.sum(decoder_all_score, dim=2)) ** 2).mean()\n",
#     212     "                    \n",
#     213     "                    acc = topk_accuracy(decoder_all_output[:, :-1, :], cap[:, 1:], Trainer.config.topk, Trainer.tokenizer.eos_token_id)\n",
#     214     "                    print('line 71, acc', acc)\n",
#     215     "                    \n",
#     216     "                    if phase == 'train':\n",
#     217     "                        loss.backward()\n",
#     218     "                        Trainer.enc_optimizer.step()\n",
#     219     "                        Trainer.dec_optimizer.step()\n",
#     220     "                    else:\n",
#     221     "                        all_val_trg.append(cap.detach().cpu())\n",
#     222     "                        all_val_output.append(decoder_all_output.detach().cpu())\n",
#     223     "\n",
#     224     "                total_loss += loss.item()*batch_size\n",
#     225     "                total_acc += acc * batch_size\n",
#     226     "                print(f'total_loss is {total_loss}, total_acc is {total_acc}')\n",
#     227     "\n",
#     228     "                if i % 100 == 0:\n",
#     229     "                    print('Epoch {}: {}/{} step loss: {}, top-{} acc: {}'.format(epoch+1, i, len(Trainer.dataloaders[phase]), loss.item(), Trainer.config.topk, acc))\n",
#     230     "                \n",
#     231     "            print('-'*20, 'enumer end', '-'*20)\n",
#     232     "\n",
#     233     "            epoch_loss = total_loss/len(Trainer.dataloaders[phase].dataset)\n",
#     234     "            epoch_acc = total_acc/len(Trainer.dataloaders[phase].dataset)\n",
#     235     "\n",
#     236     "            print(f'{phase} loss: {epoch_loss}, top-{Trainer.config.topk} acc: {epoch_acc}\\n')\n",
#     237     "\n",
#     238     "            if phase == 'train':\n",
# --> 239     "                train_loss_history.append(epoch_loss)\n",
#     240     "            if phase == 'test':\n",
#     241     "                val_loss_history.append(epoch_loss)\n",
#     242     "\n",
#     243     "                # print examples\n",
#     244     "                print_samples(cap, decoder_all_output, Trainer.tokenizer)\n",
#     245     "                print('line 100, print sample done..')\n",
#     246     "\n",
#     247     "                # calculate scores\n",
#     248     "                all_val_trg, all_val_output = tensor2list(all_val_trg, all_val_output, Trainer.tokenizer)\n",
#     249     "                print('tensor2list done')\n",
#     250     "                print(type(all_val_trg))\n",
#     251     "                print(all_val_trg)\n",
#     252     "                # val_score_history['bleu2'].append(cal_scores(all_val_trg, all_val_output, 'bleu', 2))\n",
#     253     "                print('blew2 append done')\n",
#     254     "                # val_score_history['bleu4'].append(cal_scores(all_val_trg, all_val_output, 'bleu', 4))\n",
#     255     "                print('blew4 append done')\n",
#     256     "                val_score_history['nist2'].append(cal_scores(all_val_trg, all_val_output, 'nist', 2))\n",
#     257     "                print('nist2 append done')\n",
#     258     "                val_score_history['nist4'].append(cal_scores(all_val_trg, all_val_output, 'nist', 4))\n",
#     259     "                print('nist4 append done')\n",
#     260     "                val_score_history['topk_acc'].append(epoch_acc)\n",
#     261     "                print('topk acc append done')\n",
#     262     "\n",
#     263     "                print('bleu2: {}, bleu4: {}, nist2: {}, nist4: {}'.format(val_score_history['bleu2'][-1], val_score_history['bleu4'][-1], val_score_history['nist2'][-1], val_score_history['nist4'][-1]))\n",
#     264     "                print('line 110, cal scores done')\n",
#     265     "                    \n",
#     266     "                # save best model\n",
#     267     "                early_stop += 1\n",
#     268     "\n",
#     269     "                if best_val_bleu < val_score_history['bleu4'][-1]: # 마지막 score가 더 높으면\n",
#     270     "                    early_stop = 0\n",
#     271     "                    # best_val 변경\n",
#     272     "                    best_val_bleu = val_score_history['bleu4'][-1]\n",
#     273     "                    # encoder, decorder weights 변경\n",
#     274     "                    best_enc_wts = copy.deepcopy(Trainer.encoder.state_dict())\n",
#     275     "                    best_dec_wts = copy.deepcopy(Trainer.decoder.state_dict())\n",
#     276     "                    # best epoch 변경\n",
#     277     "                    best_epoch = best_epoch_info + epoch + 1\n",
#     278     "                    # 저장\n",
#     279     "                    save_checkpoint(Trainer.model_path, [Trainer.encoder, Trainer.decoder], [Trainer.enc_optimizer, Trainer.dec_optimizer])\n",
#     280     "        print('*'*10, 'epoch end', '*'*10)\n",
#     281     "                    \n",
#     282     "        print(\"time: {} s\\n\".format(time.time() - start)) # epoch 끝\n",
#     283     "        print('\\n'*2)\n",
#     284     "\n",
#     285     "        # early stopping\n",
#     286     "        if early_stop == Trainer.config.early_stop_criterion:\n",
#     287     "                break\n",
#     288     "\n",
#     289     "    # best 값 출력\n",
#     290     "    print('best val bleu: {:4f}, best epoch: {:d}\\n'.format(best_val_bleu, best_epoch))\n",
#     291     "\n",
#     292     "    # model을 딕셔너리로\n",
#     293     "    Trainer.model = {'encoder': Trainer.encoder.load_state_dict(best_enc_wts), 'decoder': Trainer.decoder.load_state_dict(best_dec_wts)}\n",
#     294     "    Trainer.loss_data = {'best_epoch': best_epoch, 'best_val_bleu': best_val_bleu, 'train_loss_history': train_loss_history, 'val_loss_history': val_loss_history, 'val_score_history': val_score_history}\n",
#     295     "\n",
#     296     "    return Trainer.model, Trainer.loss_data"
#     297    ]
#     298   }
#     299  ],
#     300  "metadata": {
#     301   "kernelspec": {
#     302    "display_name": "env01",
#     303    "language": "python",
#     304    "name": "python3"
#     305   },
#     306   "language_info": {
#     307    "codemirror_mode": {
#     308     "name": "ipython",
#     309     "version": 3
#     310    },
#     311    "file_extension": ".py",
#     312    "mimetype": "text/x-python",
#     313    "name": "python",
#     314    "nbconvert_exporter": "python",
#     315    "pygments_lexer": "ipython3",
#     316    "version": "3.12.3"
#     317   }
#     318  },
#     319  "nbformat": 4,
#     320  "nbformat_minor": 2
#     321 }
#
# IndexError: list index out of range
